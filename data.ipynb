# %%
import pandas as pd
from tqdm import tqdm

# %%
df = pd.read_csv("Files/gitapress_v3_sn_hi_uvach_removed.csv")

df.head()
# Out:
#                                                   sa  \
# 0  ब्रह्मादयः सुरगणा मुनयोऽथ सिद्धाः सत्त्वैकतानम...
# 1  ताभ्यः पुरुषमानयत्ता अब्रुवन् सुकृतं वतेति पुर...
# 2  इति श्रीमहाभारते शान्तिपर्वणि आपद्धर्मपर्वणि ल...
# 3  न कामाननुरुद्ध्येत दुःखं कामेषु वै रतिः प्राप्...
# 4  यज्ञशिष्टाशिनः सन्तो मुच्यन्ते सर्वकिल्बिषैः भ...
#
#                                                   hi
# 0  प्रह्लादजी बोले जिनकी बुद्धि एकमात्र सत्त्वगुण...
# 1  वह उनके लिये पुरुष ले आया वे बोले'यह सुन्दर बन...
# 2  इस प्रकार श्रीमहाभारत शान्तिपर्वके अन्तर्गत आप...
# 3  इसलिये कामनाओं या भोगोंकी वृद्धिके लिये आग्रह ...
# 4  कारण कि यज्ञसे शेष बचे हुए अन्नको खानेवाले श्र...

# %% [markdown]
# # Skrutable Meter

# %%
import skrutable.utils as _utils
_utils._DEBUG_TIMING = True

from skrutable.meter_identification import MeterIdentifier, flush_profiling_report

MI = MeterIdentifier()
# for verse in my_verses:
#     MI.identify_meter(verse, resplit_option="resplit_lite", resplit_keep_midpoint=True, from_scheme="IAST")  # e.g.

# flush_profiling_report()

# %%
verse = df.loc[0, 'sa']
verse
# Out:
# 'ब्रह्मादयः सुरगणा मुनयोऽथ सिद्धाः सत्त्वैकतानमतयो वचसां प्रवाहैः नाराधितुं पुरुगुणैरधुनापि पित्रः किं तोष्टुमर्हति स मे हरिरुग्रजातेः ॥'

# %%
meter_info = MI.identify_meter(verse, resplit_option="resplit_lite", resplit_keep_midpoint=True, from_scheme="DEV")

# %%
meter_info.meter_label
# Out:
# 'vasantatilakā [14: tBjjgg]'

# %%
print(meter_info.text_syllabified.split())
# Out:
# ['bra', 'hmA', 'da', 'yaH', 'su', 'ra', 'ga', 'RA', 'mu', 'na', 'yo', "'Ta", 'si', 'dDAH', 'sa', 'ttvE', 'ka', 'tA', 'na', 'ma', 'ta', 'yo', 'va', 'ca', 'sAM', 'pra', 'vA', 'hEH', 'nA', 'rA', 'Di', 'tuM', 'pu', 'ru', 'gu', 'RE', 'ra', 'Du', 'nA', 'pi', 'pi', 'traH', 'kiM', 'to', 'zwu', 'ma', 'rha', 'ti', 'sa', 'me', 'ha', 'ri', 'ru', 'gra', 'jA', 'teH']

# %%
df['skr_out'] = ""


for i, r in tqdm(df.iterrows(), total=df.shape[0]):
    verse = df.loc[i, 'sa']
    meter_info = MI.identify_meter(verse, resplit_option="resplit_lite", resplit_keep_midpoint=True, from_scheme="DEV")
    df.loc[i, 'skr_out'] = meter_info.meter_label
# Out:
# 100%|██████████| 74941/74941 [21:27<00:00, 58.21it/s]

# %%
df['skr_out'].unique()
# Out:
# array(['vasantatilakā [14: tBjjgg]',
#        'upagīti (ardha 2: adhikamātrā, 27→28)',
#        'āryā (ardha 1: ūnamātrā, 30→28; ardha 2: ūnamātrā, 27→26)', ...,
#        'upajāti triṣṭubh: rathoddhatā 1; upendravajrā 2; svāgatā 3; ajñātam 4 (pāda 1 adhikākṣarā; pāda 3 vikṛtavṛtta; pāda 4 adhikākṣarā)',
#        'ajñātasamavṛtta [5: Blg] (pāda 1 vikṛtavṛtta; pāda 4 adhikākṣarā)',
#        'anuṣṭubh (ardham eva: asamīcīnā, [caturthāt ...] yujo j) atha vā ajñātasamavṛtta [4: yl] (pāda 1 vikṛtavṛtta)'],
#       shape=(3676,), dtype=object)

# %%
f = open('unique_skr_out.txt', 'a')

for skr_out in df['skr_out'].unique():
    f.write(skr_out+"\n")

# %%
df['syllable_count'] = ""

for i, r in tqdm(df.iterrows(), total=df.shape[0]):
    verse = df.loc[i, 'sa']
    meter_info = MI.identify_meter(verse, resplit_option="resplit_lite", resplit_keep_midpoint=True, from_scheme="DEV")

    syllables = [x for x in meter_info.text_syllabified.split() if x.strip()]
    df.at[i, 'syllable_count'] = len(syllables)
# Out:
# 100%|██████████| 74941/74941 [21:23<00:00, 58.39it/s]

# %%
df.head()
# Out:
#                                                   sa  \
# 0  ब्रह्मादयः सुरगणा मुनयोऽथ सिद्धाः सत्त्वैकतानम...
# 1  ताभ्यः पुरुषमानयत्ता अब्रुवन् सुकृतं वतेति पुर...
# 2  इति श्रीमहाभारते शान्तिपर्वणि आपद्धर्मपर्वणि ल...
# 3  न कामाननुरुद्ध्येत दुःखं कामेषु वै रतिः प्राप्...
# 4  यज्ञशिष्टाशिनः सन्तो मुच्यन्ते सर्वकिल्बिषैः भ...
#
#                                                   hi  \
# 0  प्रह्लादजी बोले जिनकी बुद्धि एकमात्र सत्त्वगुण...
# 1  वह उनके लिये पुरुष ले आया वे बोले'यह सुन्दर बन...
# 2  इस प्रकार श्रीमहाभारत शान्तिपर्वके अन्तर्गत आप...
# 3  इसलिये कामनाओं या भोगोंकी वृद्धिके लिये आग्रह ...
# 4  कारण कि यज्ञसे शेष बचे हुए अन्नको खानेवाले श्र...
#
#                                              skr_out syllable_count
# 0                         vasantatilakā [14: tBjjgg]             56
# 1              upagīti (ardha 2: adhikamātrā, 27→28)             38
# 2  āryā (ardha 1: ūnamātrā, 30→28; ardha 2: ūnamā...             37
# 3                anuṣṭubh (1,2: pathyā; 3,4: pathyā)             32
# 4                anuṣṭubh (1,2: pathyā; 3,4: pathyā)             32

# %%
# 3 patterns 
# meter (
# meter [
# meter : 

# Lets search them and see if there are other pattern than these 
import re
pattern = r'^.+?[\(\[:]'


f = open('skr_out_without_bracket.txt', 'a')

for skr_out in df['skr_out'].unique():
    if bool(re.match(pattern, skr_out)):
        continue
    f.write(skr_out+"\n")
    
# Empty file result that means skrutable result only in these 3 formats

# %%
# Extracting meter name from these patterns 

# Two more patterns found; meter = and meter +

pattern = re.compile(r'^(.*?)\s*[\(\[:=+]')

def extract_meter(text):
    if not isinstance(text, str):
        return None

    m = pattern.match(text)
    if m:
        return m.group(1).strip()
    return None

# %%
df["skr_meter"] = df["skr_out"].apply(extract_meter)

# %%
df.head()
# Out:
#                                                   sa  \
# 0  ब्रह्मादयः सुरगणा मुनयोऽथ सिद्धाः सत्त्वैकतानम...
# 1  ताभ्यः पुरुषमानयत्ता अब्रुवन् सुकृतं वतेति पुर...
# 2  इति श्रीमहाभारते शान्तिपर्वणि आपद्धर्मपर्वणि ल...
# 3  न कामाननुरुद्ध्येत दुःखं कामेषु वै रतिः प्राप्...
# 4  यज्ञशिष्टाशिनः सन्तो मुच्यन्ते सर्वकिल्बिषैः भ...
#
#                                                   hi  \
# 0  प्रह्लादजी बोले जिनकी बुद्धि एकमात्र सत्त्वगुण...
# 1  वह उनके लिये पुरुष ले आया वे बोले'यह सुन्दर बन...
# 2  इस प्रकार श्रीमहाभारत शान्तिपर्वके अन्तर्गत आप...
# 3  इसलिये कामनाओं या भोगोंकी वृद्धिके लिये आग्रह ...
# 4  कारण कि यज्ञसे शेष बचे हुए अन्नको खानेवाले श्र...
#
#                                              skr_out syllable_count  \
# 0                         vasantatilakā [14: tBjjgg]             56
# 1              upagīti (ardha 2: adhikamātrā, 27→28)             38
# 2  āryā (ardha 1: ūnamātrā, 30→28; ardha 2: ūnamā...             37
# 3                anuṣṭubh (1,2: pathyā; 3,4: pathyā)             32
# 4                anuṣṭubh (1,2: pathyā; 3,4: pathyā)             32
#
#        skr_meter
# 0  vasantatilakā
# 1        upagīti
# 2           āryā
# 3       anuṣṭubh
# 4       anuṣṭubh

# %%
df['skr_meter'].unique()
# Out:
# array(['vasantatilakā', 'upagīti', 'āryā', 'anuṣṭubh', 'upajāti triṣṭubh',
#        None, 'indravajrā', 'puṣpitāgrā', 'āryāgīti', 'śārdūlavikrīḍita',
#        'ajñātasamavṛtta', 'mālinī', 'drutavilambita', 'upajāti jagatī',
#        'mandākrāntā', 'pramāṇikā', 'udgīti', 'gīti', 'śālinī',
#        'mattamayūra', 'vaṃśastha', 'bhujaṅgaprayāta', 'kanyā',
#        'śikhariṇī', 'vidyumālā', 'pṛthvī', 'svāgatā', 'sragdharā',
#        'rathoddhatā', 'upendravajrā', 'viyoginī', 'vaiśvadevī',
#        'praharṣiṇī', 'toṭaka', 'somarājī', 'śaśivadanā', 'dodhaka',
#        'rucirā', 'madhumatī', 'narkuṭaka', 'vidyullekhā', 'indravaṃśā',
#        'vātormī', 'aparavaktra', 'aupacchandasika', 'mallikāmālā',
#        'pañcacāmara', 'hariṇī', 'śravaṇābharaṇam', 'praharaṇakalikā',
#        'tanumadhyamā', 'sragviṇī', 'madalekhā', 'cārucāmara', 'gajagati',
#        'mālatī', 'tāmarasa', 'pañcakāvalī', 'kumāralalitā',
#        'mañjubhāṣiṇī', 'śaśikalā', 'tvaritagati'], dtype=object)

# %%
df[df['skr_meter'].isna()].shape
# Out:
# (11669, 5)

# %%
df.isna().sum()
# Out:
# sa                    0
# hi                    0
# skr_out               0
# syllable_count        0
# skr_meter         11669
# dtype: int64

# %% [markdown]
# # Chanda Detector

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("chandas-detector").resolve()))

import chandas_detector

# %%
from chandas_detector import detect_meter, format_result

verse = """
काष्ठं जनः कुलधनैरनुरञ्जनीयस्
तन्नो यदुक्तमशिवं न हि तत्क्षमं ते।
नैसर्गिकी सुरभिणः कुसुमस्य सिद्धा
मूर्ध्नि स्थितिर्न चरणैरवताडनानि
"""

result = detect_meter(verse)

if result.confidence == "exact":
    print(f"Detected: {result.meter}")
else:
    print("Could not verify meter.")

# Print the formatted text diagnostic representation
print(format_result(result))
# Out:
# Detected: Vasantatilakā
# ============================================================
#   Chandas Detector — Analysis Result
# ============================================================
#   Pāda 1: GGLGLLLGLLGLGG  (14 syllables)
#           [GGL | GLL | LGL | LGL | GG]
#   Pāda 2: GGLGLLLGLLGLGG  (14 syllables)
#           [GGL | GLL | LGL | LGL | GG]
#   Pāda 3: GGLGLLLGLLGLGG  (14 syllables)
#           [GGL | GLL | LGL | LGL | GG]
#   Pāda 4: GGLGLLLGLLGLGL  (14 syllables)
#           [GGL | GLL | LGL | LGL | GL]
# ------------------------------------------------------------
#   ✓ Detected Meter : Vasantatilakā
#     Gaṇa Structure : त भ ज ज ग ग
#     Yati (Caesura)  : 8 + 6
#     Confidence     : exact
# ============================================================

# %%
result.meter
# Out:
# 'Vasantatilakā'

# %%
meter_codes = []

for r in tqdm(df.itertuples(index=False), total=len(df)):
    verse = r.sa.strip()
    result = detect_meter(verse)

    meter_codes.append(result.meter if result.confidence == "exact" else None)

df["meter_cd"] = meter_codes
# Out:
#   0%|          | 0/74941 [00:00<?, ?it/s]
# 100%|██████████| 74941/74941 [00:23<00:00, 3172.53it/s]
# /tmp/ipykernel_474807/2030493013.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["meter_cd"] = meter_codes

# %%
df.head()
# Out:
#                                                   sa  \
# 0  ब्रह्मादयः सुरगणा मुनयोऽथ सिद्धाः सत्त्वैकतानम...
# 1  ताभ्यः पुरुषमानयत्ता अब्रुवन् सुकृतं वतेति पुर...
# 2  इति श्रीमहाभारते शान्तिपर्वणि आपद्धर्मपर्वणि ल...
# 3  न कामाननुरुद्ध्येत दुःखं कामेषु वै रतिः प्राप्...
# 4  यज्ञशिष्टाशिनः सन्तो मुच्यन्ते सर्वकिल्बिषैः भ...
#
#                                                   hi  \
# 0  प्रह्लादजी बोले जिनकी बुद्धि एकमात्र सत्त्वगुण...
# 1  वह उनके लिये पुरुष ले आया वे बोले'यह सुन्दर बन...
# 2  इस प्रकार श्रीमहाभारत शान्तिपर्वके अन्तर्गत आप...
# 3  इसलिये कामनाओं या भोगोंकी वृद्धिके लिये आग्रह ...
# 4  कारण कि यज्ञसे शेष बचे हुए अन्नको खानेवाले श्र...
#
#                                              skr_out syllable_count  \
# 0                         vasantatilakā [14: tBjjgg]             56
# 1              upagīti (ardha 2: adhikamātrā, 27→28)             38
# 2  āryā (ardha 1: ūnamātrā, 30→28; ardha 2: ūnamā...             37
# 3                anuṣṭubh (1,2: pathyā; 3,4: pathyā)             32
# 4                anuṣṭubh (1,2: pathyā; 3,4: pathyā)             32
#
#        skr_meter       meter_cd
# 0  vasantatilakā  Vasantatilakā
# 1        upagīti           None
# 2           āryā           None
# 3       anuṣṭubh       Anuṣṭubh
# 4       anuṣṭubh       Anuṣṭubh

# %%
df['meter_cd'].unique()
# Out:
# array(['Vasantatilakā', None, 'Anuṣṭubh', 'Śārdūlavikrīḍita', 'Mālinī',
#        'Indravajrā', 'Śālinī', 'Vaṃśastha', 'Śikhariṇī', 'Upendravajrā',
#        'Sragdharā'], dtype=object)

# %%
valid_syllable_count = {
    'Vasantatilakā':56,
    'Anuṣṭubh':32,
    'Śārdūlavikrīḍita':76,
    'Mālinī':60,
    'Indravajrā':44,
    'Śālinī':44,
    'Vaṃśastha':48,
    'Śikhariṇī':68,
    'Upendravajrā':44,
    'Sragdharā':84
}

# %%
df.isnull().sum()
# Out:
# sa                    0
# hi                    0
# skr_out               0
# syllable_count        0
# skr_meter         11669
# meter_cd          45731
# dtype: int64

# %%
df["comments"] = None

for row in tqdm(df.itertuples(index=True), total=len(df)):
    comments = []

    if row.meter_cd is not None:
        if (
            row.skr_meter is None
            or row.meter_cd.strip().lower() != row.skr_meter.strip().lower()
        ):
            comments.append("Skrutable Mismatch")

        if row.syllable_count != valid_syllable_count[row.meter_cd]:
            comments.append("Syllable Count Error")

    if comments:
        df.at[row.Index, "comments"] = " + ".join(comments)
# Out:
# /tmp/ipykernel_474807/139302383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["comments"] = None
# 100%|██████████| 74941/74941 [00:00<00:00, 618226.14it/s]

# %%
df.head()
# Out:
#                                                   sa  \
# 0  ब्रह्मादयः सुरगणा मुनयोऽथ सिद्धाः सत्त्वैकतानम...
# 1  ताभ्यः पुरुषमानयत्ता अब्रुवन् सुकृतं वतेति पुर...
# 2  इति श्रीमहाभारते शान्तिपर्वणि आपद्धर्मपर्वणि ल...
# 3  न कामाननुरुद्ध्येत दुःखं कामेषु वै रतिः प्राप्...
# 4  यज्ञशिष्टाशिनः सन्तो मुच्यन्ते सर्वकिल्बिषैः भ...
#
#                                                   hi  \
# 0  प्रह्लादजी बोले जिनकी बुद्धि एकमात्र सत्त्वगुण...
# 1  वह उनके लिये पुरुष ले आया वे बोले'यह सुन्दर बन...
# 2  इस प्रकार श्रीमहाभारत शान्तिपर्वके अन्तर्गत आप...
# 3  इसलिये कामनाओं या भोगोंकी वृद्धिके लिये आग्रह ...
# 4  कारण कि यज्ञसे शेष बचे हुए अन्नको खानेवाले श्र...
#
#                                              skr_out syllable_count  \
# 0                         vasantatilakā [14: tBjjgg]             56
# 1              upagīti (ardha 2: adhikamātrā, 27→28)             38
# 2  āryā (ardha 1: ūnamātrā, 30→28; ardha 2: ūnamā...             37
# 3                anuṣṭubh (1,2: pathyā; 3,4: pathyā)             32
# 4                anuṣṭubh (1,2: pathyā; 3,4: pathyā)             32
#
#        skr_meter       meter_cd comments
# 0  vasantatilakā  Vasantatilakā     None
# 1        upagīti           None     None
# 2           āryā           None     None
# 3       anuṣṭubh       Anuṣṭubh     None
# 4       anuṣṭubh       Anuṣṭubh     None

# %%
df['comments'].unique()
# Out:
# array([None, 'Skrutable Mismatch'], dtype=object)

# %%
df[df['comments'] == 'Skrutable Mismatch'].shape
# Out:
# (27, 7)

# %%
df[df['comments'] == 'Skrutable Mismatch']
# Out:
#                                                       sa  \
# 5140   चापपाणि: सुतीक्ष्येषु; कवची हेममालिक: सितप्राव...
# 5917   नारदे तु गते स्वर्गे सर्वे ते पृथिवीभुजः विस्म...
# 9491   एष धारयिता सम्यक् चातुर्वर्ण्य, महाबलः शुभाशुभ...
# 13891  तसात्‌ सङ्गो न कर्तव्य; ख्रीष ख्रेणेषु चेन्द्र...
# 22105  यावद्‌ देदेन्द्रियप्राणैरात्मन; सन्निकर्षणस्‌ ...
# 23127  नीपार्जुनकदम्बानां पृथिव्यां चातिवृष्टिभि: गन्...
# 24690  ताराचित्रपिनद्धाड़ं, स्वर्णकूबरभूषितम्‌ सुपताक...
# 25464  एतस्मिन्नन्तरे क्रुद्ध/ कालनेमिर्महासुरः व्यवर...
# 25996  त्र्यक्षरं परमं ब्रह्म गोविन्द, त्र्यक्षरं परम...
# 27493  परिरम्भो हि मे लोके दुर्लभः परमात्मनः अतस्त्वं...
# 27596  अहमास्माऽऽन्तरो बाह्योच्नाइत; सर्वदेहिनाम्‌ यथ...
# 32186  इत्युक्तो लोकनाथेन स्वयम्भू; प्रणिपत्य तम्‌ सह...
# 33399  शुचिः सम्मुखमासीन; प्राणसंयमनादिभिः पिण्डं विश...
# 35020  विष्णु: श्रृड़समुद्धूतं प्रगृह्य विपुलं धनुः प...
# 36426  वामनो हासुरेन्द्रस्य चिकीर्षु; कदनं महत्‌ क्षि...
# 43053  यं न योगेन सांख्येन दानव्रततपोऽभ्वरेः व्याख्या...
# 45813  वत्सावते त्वपुत्राय वसुदेव:ः प्रतापवान्‌ अद्/ि...
# 49420  प्रकृति; पुरुपश्चेति विकल्पः पुरुपर्षम एष वैका...
# 52947  कपोती प्रथमं गर्भ गृह्ृती काल आगते अण्डानि सुष...
# 55421  तयोरेकतरो ह्यर्थः प्रकृति; सोभयात्मिका ज्ञानं ...
# 55854  तपस्येवाभवन् सर्वे सर्वे धर्ममनुव्रताः पृथिव्य...
# 57247  किं दानं किं तपः शौर्य किं सत्यसृतमुच्यते कस्त...
# 64169  यदुनेवं महाभागो ब्रह्मण्येन सुमेधसा पृष्ट, सभा...
# 67089  यथाग्निः सुसमृद्धाचि; करोत्येधांसि भस्मसात्‌ त...
# 72681  एवं, वर्णस्य वर्णस्य समुष्चीय सहस्रशः यथा समुद...
# 72845  तत्तत्‌ सास्विकमेवेषां यद्‌ यद्‌ वृद्धा; प्रचक...
# 73079  घान्यदावेखितन्तूनां रसतैजसचर्मणाम्‌ कालवाय्वम्...
#
#                                                       hi  \
# 5140   उसके हाथमें धनुष और तीखे बाण शोभा पाते थे वह क...
# 5917   नारदजीके स्वर्गलोकको चले जानेपर वे समस्त भूपाल...
# 9491   यह महावली राजकुमार चारों वर्णोंको भलीभाँति धार...
# 13891  अतः वाणी) कान और मन आदि इन्द्रियोसि क्षो और खी...
# 22105  भगवान्‌ श्रीकृष्णने कहावस्तुतः प्रिय उद्धव ! स...
# 23127  पृथ्वीपर अत्यन्त वर्षा होनेके कारण नीप, अर्जुन...
# 24690  उसके सारे अक्ग तारिकाओंके चित्रसे व्याप्त थे स...
# 25464  इसी बीच कुपित हुआ महान्‌ असुर कालनेमि समुद्रकी...
# 25996  गोविन्द' नाम के तीनों अक्षर परम ब्रह्म स्वरूप ...
# 27493  संसारमें मुझ परमात्माका आलिङ्गन मिलना अत्यन्त ...
# 27596  जैसे स्थूळ पञ्चयूर्तोमे बाहर, भीतरसर्त्र सूक्ष...
# 32186  श्रीशुकदेवजी कहते हैँ परीक्षित्‌ ! जब अखिळलोका...
# 33399  पहले स्नानादिसे शरीर और संतोष आदिसे अन्त: करणक...
# 35020  उधर महाबाहु भगवान्‌ विष्णु श्रुड़से निर्मित हु...
# 36426  भगवान्‌ वामन असुरराज बलिकी बड़ी भारी हानि करना...
# 43053  उद्धव  बड़ेबड़े प्रयत्नशील साधक योग, सांख्य, द...
# 45813  शूरनन्दन प्रतापी वसुदेवजीने पुत्रहीन वत्सावानक...
# 49420  भगवान्‌ श्रीक्ष्णने कहाउद्भवजी ! प्रकृति और पु...
# 52947  समय आनेपर कबूतरीको पहला गर्भ रहा उसने षँ 'पतिक...
# 55421  उनमेंसे एक वस्तुको प्रकृति कहते हैं उसीने जगत ...
# 55854  धर्मात्मा राजा रामके राज्यमै पृथ्वीपर सच लोग त...
# 57247  आप मुझे दान, तपस्या, शूरता, सत्य ओर ऋका भी सहा...
# 64169  भगवान श्रीकृष्णने कहाउद्धव ! हमारे पूर्वज महार...
# 67089  उद्धव  जैसे धधकती हुई आग लकड़ियोंके बड़े ढेरको...
# 72681  इसी प्रकार प्रत्येक वर्णके हजारों चुने हुए योद...
# 72845  इनमेंसे शाब्नज्ञ महात्मा जिनकी प्रशंसा करते है...
# 73079  अनाज, लकडी, _हाथीदाँत आदि हड्डी, सूत, मधु, नमक...
#
#                       skr_out syllable_count skr_meter  meter_cd  \
# 5140   na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 5917   na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 9491   na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 13891  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 22105  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 23127  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 24690  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 25464  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 25996  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 27493  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 27596  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 32186  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 33399  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 35020  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 36426  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 43053  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 45813  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 49420  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 52947  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 55421  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 55854  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 57247  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 64169  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 67089  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 72681  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 72845  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
# 73079  na kiṃcid adhyavasitam             32      None  Anuṣṭubh
#
#                  comments
# 5140   Skrutable Mismatch
# 5917   Skrutable Mismatch
# 9491   Skrutable Mismatch
# 13891  Skrutable Mismatch
# 22105  Skrutable Mismatch
# 23127  Skrutable Mismatch
# 24690  Skrutable Mismatch
# 25464  Skrutable Mismatch
# 25996  Skrutable Mismatch
# 27493  Skrutable Mismatch
# 27596  Skrutable Mismatch
# 32186  Skrutable Mismatch
# 33399  Skrutable Mismatch
# 35020  Skrutable Mismatch
# 36426  Skrutable Mismatch
# 43053  Skrutable Mismatch
# 45813  Skrutable Mismatch
# 49420  Skrutable Mismatch
# 52947  Skrutable Mismatch
# 55421  Skrutable Mismatch
# 55854  Skrutable Mismatch
# 57247  Skrutable Mismatch
# 64169  Skrutable Mismatch
# 67089  Skrutable Mismatch
# 72681  Skrutable Mismatch
# 72845  Skrutable Mismatch
# 73079  Skrutable Mismatch

# %%
df.to_csv("v3_gitapress_meter_analysed.csv", index=False)

# %%
df.isnull().sum()
# Out:
# sa                    0
# hi                    0
# skr_out               0
# syllable_count        0
# skr_meter         11669
# meter_cd          45731
# comments          74914
# dtype: int64

# %%
df['skr_meter'].unique()
# Out:
# array(['vasantatilakā', 'upagīti', 'āryā', 'anuṣṭubh', 'upajāti triṣṭubh',
#        None, 'indravajrā', 'puṣpitāgrā', 'āryāgīti', 'śārdūlavikrīḍita',
#        'ajñātasamavṛtta', 'mālinī', 'drutavilambita', 'upajāti jagatī',
#        'mandākrāntā', 'pramāṇikā', 'udgīti', 'gīti', 'śālinī',
#        'mattamayūra', 'vaṃśastha', 'bhujaṅgaprayāta', 'kanyā',
#        'śikhariṇī', 'vidyumālā', 'pṛthvī', 'svāgatā', 'sragdharā',
#        'rathoddhatā', 'upendravajrā', 'viyoginī', 'vaiśvadevī',
#        'praharṣiṇī', 'toṭaka', 'somarājī', 'śaśivadanā', 'dodhaka',
#        'rucirā', 'madhumatī', 'narkuṭaka', 'vidyullekhā', 'indravaṃśā',
#        'vātormī', 'aparavaktra', 'aupacchandasika', 'mallikāmālā',
#        'pañcacāmara', 'hariṇī', 'śravaṇābharaṇam', 'praharaṇakalikā',
#        'tanumadhyamā', 'sragviṇī', 'madalekhā', 'cārucāmara', 'gajagati',
#        'mālatī', 'tāmarasa', 'pañcakāvalī', 'kumāralalitā',
#        'mañjubhāṣiṇī', 'śaśikalā', 'tvaritagati'], dtype=object)

# %%
df['meter_cd'].unique()
# Out:
# array(['Vasantatilakā', None, 'Anuṣṭubh', 'Śārdūlavikrīḍita', 'Mālinī',
#        'Indravajrā', 'Śālinī', 'Vaṃśastha', 'Śikhariṇī', 'Upendravajrā',
#        'Sragdharā'], dtype=object)

# %% [markdown]
# # FInal analysis and split

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/shivraj-pg/v3_poetrygen_new/v3_gitapress_meter_analysed.csv")

df.head()
# Out:
#                                                   sa  \
# 0  ब्रह्मादयः सुरगणा मुनयोऽथ सिद्धाः सत्त्वैकतानम...
# 1  ताभ्यः पुरुषमानयत्ता अब्रुवन् सुकृतं वतेति पुर...
# 2  इति श्रीमहाभारते शान्तिपर्वणि आपद्धर्मपर्वणि ल...
# 3  न कामाननुरुद्ध्येत दुःखं कामेषु वै रतिः प्राप्...
# 4  यज्ञशिष्टाशिनः सन्तो मुच्यन्ते सर्वकिल्बिषैः भ...
#
#                                                   hi  \
# 0  प्रह्लादजी बोले जिनकी बुद्धि एकमात्र सत्त्वगुण...
# 1  वह उनके लिये पुरुष ले आया वे बोले'यह सुन्दर बन...
# 2  इस प्रकार श्रीमहाभारत शान्तिपर्वके अन्तर्गत आप...
# 3  इसलिये कामनाओं या भोगोंकी वृद्धिके लिये आग्रह ...
# 4  कारण कि यज्ञसे शेष बचे हुए अन्नको खानेवाले श्र...
#
#                                              skr_out  syllable_count  \
# 0                         vasantatilakā [14: tBjjgg]              56
# 1              upagīti (ardha 2: adhikamātrā, 27→28)              38
# 2  āryā (ardha 1: ūnamātrā, 30→28; ardha 2: ūnamā...              37
# 3                anuṣṭubh (1,2: pathyā; 3,4: pathyā)              32
# 4                anuṣṭubh (1,2: pathyā; 3,4: pathyā)              32
#
#        skr_meter       meter_cd comments
# 0  vasantatilakā  Vasantatilakā      NaN
# 1        upagīti            NaN      NaN
# 2           āryā            NaN      NaN
# 3       anuṣṭubh       Anuṣṭubh      NaN
# 4       anuṣṭubh       Anuṣṭubh      NaN

# %%
df.isnull().sum()
# Out:
# sa                    0
# hi                    0
# skr_out               0
# syllable_count        0
# skr_meter         11669
# meter_cd          45731
# comments          74914
# dtype: int64

# %%
df['skr_meter'].unique()
# Out:
# array(['vasantatilakā', 'upagīti', 'āryā', 'anuṣṭubh', 'upajāti triṣṭubh',
#        nan, 'indravajrā', 'puṣpitāgrā', 'āryāgīti', 'śārdūlavikrīḍita',
#        'ajñātasamavṛtta', 'mālinī', 'drutavilambita', 'upajāti jagatī',
#        'mandākrāntā', 'pramāṇikā', 'udgīti', 'gīti', 'śālinī',
#        'mattamayūra', 'vaṃśastha', 'bhujaṅgaprayāta', 'kanyā',
#        'śikhariṇī', 'vidyumālā', 'pṛthvī', 'svāgatā', 'sragdharā',
#        'rathoddhatā', 'upendravajrā', 'viyoginī', 'vaiśvadevī',
#        'praharṣiṇī', 'toṭaka', 'somarājī', 'śaśivadanā', 'dodhaka',
#        'rucirā', 'madhumatī', 'narkuṭaka', 'vidyullekhā', 'indravaṃśā',
#        'vātormī', 'aparavaktra', 'aupacchandasika', 'mallikāmālā',
#        'pañcacāmara', 'hariṇī', 'śravaṇābharaṇam', 'praharaṇakalikā',
#        'tanumadhyamā', 'sragviṇī', 'madalekhā', 'cārucāmara', 'gajagati',
#        'mālatī', 'tāmarasa', 'pañcakāvalī', 'kumāralalitā',
#        'mañjubhāṣiṇī', 'śaśikalā', 'tvaritagati'], dtype=object)

# %%
df['meter_cd'].unique()
# Out:
# array(['Vasantatilakā', nan, 'Anuṣṭubh', 'Śārdūlavikrīḍita', 'Mālinī',
#        'Indravajrā', 'Śālinī', 'Vaṃśastha', 'Śikhariṇī', 'Upendravajrā',
#        'Sragdharā'], dtype=object)

# %%
skr_cd_meter_dict = {
    'vasantatilakā': 'Vasantatilakā',
    'anuṣṭubh': 'Anuṣṭubh',
    'śārdūlavikrīḍita': 'Śārdūlavikrīḍita',
    'mālinī': 'Mālinī',
    'indravajrā': 'Indravajrā',
    'śālinī': 'Śālinī',
    'vaṃśastha': 'Vaṃśastha',
    'śikhariṇī': 'Śikhariṇī',
    'upendravajrā': 'Upendravajrā',
    'sragdharā':'Sragdharā'
}

# %%
df['skr_meter'] = df['skr_meter'].replace(skr_cd_meter_dict)

# %%
final_df = df[df['skr_meter'] == df['meter_cd']]
final_df.shape
# Out:
# (29183, 7)

# %%
final_df['skr_meter'].unique()
# Out:
# array(['Vasantatilakā', 'Anuṣṭubh', 'Śārdūlavikrīḍita', 'Mālinī',
#        'Indravajrā', 'Śālinī', 'Vaṃśastha', 'Śikhariṇī', 'Upendravajrā',
#        'Sragdharā'], dtype=object)

# %%
final_df['meter_cd'].unique()
# Out:
# array(['Vasantatilakā', 'Anuṣṭubh', 'Śārdūlavikrīḍita', 'Mālinī',
#        'Indravajrā', 'Śālinī', 'Vaṃśastha', 'Śikhariṇī', 'Upendravajrā',
#        'Sragdharā'], dtype=object)

# %%
final_df.head()
# Out:
#                                                   sa  \
# 0  ब्रह्मादयः सुरगणा मुनयोऽथ सिद्धाः सत्त्वैकतानम...
# 3  न कामाननुरुद्ध्येत दुःखं कामेषु वै रतिः प्राप्...
# 4  यज्ञशिष्टाशिनः सन्तो मुच्यन्ते सर्वकिल्बिषैः भ...
# 5  स देवप्रस्थमासाद्य सेनाविन्दोः पुरं प्रति बलेन...
# 7  अहोरात्रेक्षणो दिव्यो वेदाड़ः श्रुतिभूषण: आज्य...
#
#                                                   hi  \
# 0  प्रह्लादजी बोले जिनकी बुद्धि एकमात्र सत्त्वगुण...
# 3  इसलिये कामनाओं या भोगोंकी वृद्धिके लिये आग्रह ...
# 4  कारण कि यज्ञसे शेष बचे हुए अन्नको खानेवाले श्र...
# 5  वहाँसे सेनाविन्दुकी राजधानी देवप्रश्वमें आकर च...
# 7  दिन और रात्रि उनके नेत्र हैं, वे दिव्यस्वरूप ह...
#
#                                skr_out  syllable_count      skr_meter  \
# 0           vasantatilakā [14: tBjjgg]              56  Vasantatilakā
# 3  anuṣṭubh (1,2: pathyā; 3,4: pathyā)              32       Anuṣṭubh
# 4  anuṣṭubh (1,2: pathyā; 3,4: pathyā)              32       Anuṣṭubh
# 5  anuṣṭubh (1,2: pathyā; 3,4: pathyā)              32       Anuṣṭubh
# 7  anuṣṭubh (1,2: pathyā; 3,4: pathyā)              32       Anuṣṭubh
#
#         meter_cd comments
# 0  Vasantatilakā      NaN
# 3       Anuṣṭubh      NaN
# 4       Anuṣṭubh      NaN
# 5       Anuṣṭubh      NaN
# 7       Anuṣṭubh      NaN

# %%
final_df.to_csv("v3_gitapress_skr_equal_verifier.csv", index=False)
